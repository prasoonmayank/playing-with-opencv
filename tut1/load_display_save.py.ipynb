# %%
from __future__ import print_function
import argparse
import cv2

# %%
img = cv2.imread("../images/47fc63796575313646ba35be2daf27da.jpg")
print("width: {} pixels".format(img.shape[1]))
print("height: {} pixels".format(img.shape[0]))
print("channels: {}".format(img.shape[2]))
# Out:
# width: 400 pixels
# height: 533 pixels
# channels: 3

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(img)

# %%
print(img[1][1][0])
# Out:
# 35

# %%
(b,g,r) = img[0,0]
print("Pixel at (0,0) - Red: {}, Green: {}, Blue: {}".format(r,g,b))

img[0,0] = (0,0,255)
(b,g,r) = img[0,0]
for i in range(0,100):
    for j in range(0,100):
        (b,g,r) = img[i,j]
print("Pixel at (0,0) - Red: {}, Green: {}, Blue: {}".format(r,g,b))
# Out:
# Pixel at (0,0) - Red: 255, Green: 0, Blue: 0
# Pixel at (0,0) - Red: 38, Green: 38, Blue: 38

# %%
plt.imshow(img)

# %%
corner = img[0:100,0:100]
# %matplotlib inline
plt.imshow(img)

# %%
img[0:100,0:100] = (0,255,0)

plt.imshow(img)

# %%
plt.imshow(corner)
