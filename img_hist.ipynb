# %%
import numpy as np
import cv2

img = cv2.imread("images/nelsonmandela1-2x.jpg")

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.imshow(img)

# %%
eq = cv2.equalizeHist(img)

plt.imshow(eq)
